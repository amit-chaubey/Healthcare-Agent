# %%
print("notebook running")
# Out:
# notebook running

# %%
import sys
print(sys.executable)
# Out:
# /Users/amitchoubey/Documents/Projects/Agents/Healthcare-Agent/venv/bin/python

# %%
# !pip list
# Out:
# Package                   Version
# ------------------------- --------------
# anyio                     4.8.0
# appnope                   0.1.4
# argon2-cffi               23.1.0
# argon2-cffi-bindings      21.2.0
# arrow                     1.3.0
# asttokens                 3.0.0
# async-lru                 2.0.4
# attrs                     24.3.0
# babel                     2.16.0
# beautifulsoup4            4.12.3
# bleach                    6.2.0
# certifi                   2024.12.14
# cffi                      1.17.1
# charset-normalizer        3.4.1
# comm                      0.2.2
# contourpy                 1.3.1
# cycler                    0.12.1
# debugpy                   1.8.12
# decorator                 5.1.1
# defusedxml                0.7.1
# executing                 2.2.0
# fastjsonschema            2.21.1
# fonttools                 4.55.5
# fqdn                      1.5.1
# h11                       0.14.0
# httpcore                  1.0.7
# ...

# %%
import pandas as pd
import numpy as np
# import seabo
# rn as sns

# %%
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 import matplotlib.pyplot as plt
#
# File ~/Documents/Projects/Agents/Healthcare-Agent/venv/lib/python3.12/site-packages/matplotlib/__init__.py:1296
#    1292     rcParams['backend_fallback'] = False
#    1295 if os.environ.get('MPLBACKEND'):
# -> 1296     rcParams['backend'] = os.environ.get('MPLBACKEND')
#    1299 def get_backend(*, auto_select=True):
#    1300     """
#    1301     Return the name of the current backend.
#    1302
#    (...)
#    1320     matplotlib.use
#    1321     """
#
# File ~/Documents/Projects/Agents/Healthcare-Agent/venv/lib/python3.12/site-packages/matplotlib/__init__.py:771, in RcParams.__setitem__(self, key, val)
#     769         cval = self.validate[key](val)
#     770     except ValueError as ve:
# --> 771         raise ValueError(f"Key {key}: {ve}") from None
# ...

# %%
import matplotlib
matplotlib.use('Agg')  # Replace 'TkAgg' with a valid backend if needed
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 import matplotlib
#       2 matplotlib.use('Agg')  # Replace 'TkAgg' with a valid backend if needed
#
# File ~/Documents/Projects/Agents/Healthcare-Agent/venv/lib/python3.12/site-packages/matplotlib/__init__.py:1296
#    1292     rcParams['backend_fallback'] = False
#    1295 if os.environ.get('MPLBACKEND'):
# -> 1296     rcParams['backend'] = os.environ.get('MPLBACKEND')
#    1299 def get_backend(*, auto_select=True):
#    1300     """
#    1301     Return the name of the current backend.
#    1302
#    (...)
#    1320     matplotlib.use
#    1321     """
#
# File ~/Documents/Projects/Agents/Healthcare-Agent/venv/lib/python3.12/site-packages/matplotlib/__init__.py:771, in RcParams.__setitem__(self, key, val)
#     769         cval = self.validate[key](val)
#     770     except ValueError as ve:
# ...

# %%
file_path = 'dataset/personal_health_data.csv'
data = pd.read_csv(file_path)

# %%
data
# Out:
#       User_ID  Age  Gender      Weight      Height Medical_Conditions  \
# 0     U_00001   61   Other   88.677623  178.524231           Diabetes
# 1     U_00002   24    Male   86.742084  200.346358                NaN
# 2     U_00003   81   Other   61.656054  195.971356       Hypertension
# 3     U_00004   70   Other  141.513794  164.178216       Hypertension
# 4     U_00005   30   Other   80.552872  146.920675           Diabetes
# ...       ...  ...     ...         ...         ...                ...
# 9995  U_09996   16  Female  143.301741  152.822616       Hypertension
# 9996  U_09997   46   Other   89.447004  168.085894       Hypertension
# 9997  U_09998   62  Female   43.284274  200.536394                NaN
# 9998  U_09999   27  Female   86.436494  162.125426           Diabetes
# 9999  U_10000   47  Female   97.284937  179.853153           Diabetes
#
#      Medication Smoker Alcohol_Consumption            Timestamp  ...  \
# ...

# %%
print(f"Dataset information: {data.info}")
# Out:
# Dataset information: <bound method DataFrame.info of       User_ID  Age  Gender      Weight      Height Medical_Conditions  \
# 0     U_00001   61   Other   88.677623  178.524231           Diabetes
# 1     U_00002   24    Male   86.742084  200.346358                NaN
# 2     U_00003   81   Other   61.656054  195.971356       Hypertension
# 3     U_00004   70   Other  141.513794  164.178216       Hypertension
# 4     U_00005   30   Other   80.552872  146.920675           Diabetes
# ...       ...  ...     ...         ...         ...                ...
# 9995  U_09996   16  Female  143.301741  152.822616       Hypertension
# 9996  U_09997   46   Other   89.447004  168.085894       Hypertension
# 9997  U_09998   62  Female   43.284274  200.536394                NaN
# 9998  U_09999   27  Female   86.436494  162.125426           Diabetes
# 9999  U_10000   47  Female   97.284937  179.853153           Diabetes
#
#      Medication Smoker Alcohol_Consumption            Timestamp  ...  \
# ...

# %%
print("Dataset shape: ")
{data.shape}
# Out:
# Dataset shape:
# {(10000, 28)}

# %%
print("Dataset type:")
data.dtypes
# Out:
# Dataset type:
# User_ID                 object
# Age                      int64
# Gender                  object
# Weight                 float64
# Height                 float64
# Medical_Conditions      object
# Medication              object
# Smoker                  object
# Alcohol_Consumption     object
# Timestamp               object
# Day_of_Week             object
# Sleep_Duration         float64
# Deep_Sleep_Duration    float64
# REM_Sleep_Duration     float64
# Wakeups                  int64
# Snoring                 object
# Heart_Rate               int64
# Blood_Oxygen_Level     float64
# ECG                     object
# Calories_Intake        float64
# Water_Intake           float64
# Stress_Level            object
# Mood                    object
# Skin_Temperature       float64
# Body_Fat_Percentage    float64
# Muscle_Mass            float64
# Health_Score           float64
# Anomaly_Flag             int64
# dtype: object

# %%
print("\nMissing Values:")
data.isnull().sum()
# Out:
# Missing Values:
# User_ID                   0
# Age                       0
# Gender                    0
# Weight                    0
# Height                    0
# Medical_Conditions     3304
# Medication                0
# Smoker                    0
# Alcohol_Consumption    3360
# Timestamp                 0
# Day_of_Week               0
# Sleep_Duration            0
# Deep_Sleep_Duration       0
# REM_Sleep_Duration        0
# Wakeups                   0
# Snoring                   0
# Heart_Rate                0
# Blood_Oxygen_Level        0
# ECG                       0
# Calories_Intake           0
# Water_Intake              0
# Stress_Level              0
# Mood                      0
# Skin_Temperature          0
# Body_Fat_Percentage       0
# Muscle_Mass               0
# Health_Score              0
# Anomaly_Flag              0
# dtype: int64

# %%
data.describe()
# Out:
#                 Age        Weight        Height  Sleep_Duration  \
# count  10000.000000  10000.000000  10000.000000    10000.000000
# mean      47.534500     90.371237    170.539415        7.014794
# std       21.892659     34.924593     17.599783        1.736720
# min       10.000000     30.001125    140.001252        4.000285
# 25%       28.000000     60.135075    155.422556        5.523986
# 50%       47.000000     89.856120    170.729185        6.992782
# 75%       67.000000    120.648181    185.740690        8.542130
# max       85.000000    150.978482    200.998406        9.999370
#
#        Deep_Sleep_Duration  REM_Sleep_Duration       Wakeups    Heart_Rate  \
# count         10000.000000        10000.000000  10000.000000  10000.000000
# mean              3.734520            3.280274      2.023800    115.521500
# std               2.131272            2.153436      1.412173     37.805117
# min               0.500598            0.000805      0.000000     50.000000
# ...

# %%
data.describe(include=['object'])
# Out:
#         User_ID  Gender Medical_Conditions Medication Smoker  \
# count     10000   10000               6696      10000  10000
# unique    10000       3                  2          2      2
# top     U_00001  Female           Diabetes         No     No
# freq          1    3363               3359       5015   5005
#
#        Alcohol_Consumption            Timestamp Day_of_Week Snoring     ECG  \
# count                 6640                10000       10000   10000   10000
# unique                   2                10000           7       2       2
# top               Moderate  2021-01-01 00:00:00      Friday      No  Normal
# freq                  3355                    1        1440    5025    5022
#
#        Stress_Level     Mood
# count         10000    10000
# unique            3        4
# top             Low  Anxious
# freq           3370     2542

# %%
# plt.figure(figsize=(10, 6))
# sns.heatmap(data.isnull(), cbar=False, cmap='viridis')
# plt.title("Missing Values Heatmap")
# plt.show()

# %%
# plt.figure(figsize=(12, 8))
# correlation = data.corr()
# sns.heatmap(correlation, annot=True, cmap='coolwarm', fmt=".2f")
# plt.title("Correlation Matrix")
# plt.show()

# %%
# # Replace 'column_name' with an actual column from the dataset
# sns.histplot(data['column_name'], kde=True)
# plt.title("Distribution of Column")
# plt.show()

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Data cleaning

# %%
# Check for missing values
print("Missing Values:")
print(data.isnull().sum())
# Out:
# Missing Values:
# User_ID                0
# Age                    0
# Gender                 0
# Weight                 0
# Height                 0
# Medical_Conditions     0
# Medication             0
# Smoker                 0
# Alcohol_Consumption    0
# Timestamp              0
# Day_of_Week            0
# Sleep_Duration         0
# Deep_Sleep_Duration    0
# REM_Sleep_Duration     0
# Wakeups                0
# Snoring                0
# Heart_Rate             0
# Blood_Oxygen_Level     0
# ECG                    0
# Calories_Intake        0
# Water_Intake           0
# Stress_Level           0
# Mood                   0
# Skin_Temperature       0
# Body_Fat_Percentage    0
# Muscle_Mass            0
# Health_Score           0
# Anomaly_Flag           0
# dtype: int64

# %%
# Fill missing numeric values with mean
numeric_columns = data.select_dtypes(include=['float64', 'int64']).columns
data[numeric_columns] = data[numeric_columns].fillna(data[numeric_columns].mean())

# %%
# Fill missing categorical values with mode
categorical_columns = data.select_dtypes(include=['object']).columns
data[categorical_columns] = data[categorical_columns].fillna(data[categorical_columns].mode().iloc[0])

# %%
import os
print(os.environ.get('MPLBACKEND'))
# Out:
# module://matplotlib_inline.backend_inline

# %%
import os
os.environ.pop('MPLBACKEND', None)
# Out:
# 'module://matplotlib_inline.backend_inline'

# %%
import matplotlib
matplotlib.use('Agg')  # Use a non-interactive backend
import matplotlib.pyplot as plt

# %%
import matplotlib
print(matplotlib.matplotlib_fname())
# Out:
# /Users/amitchoubey/Documents/Projects/Agents/Healthcare-Agent/venv/lib/python3.12/site-packages/matplotlib/mpl-data/matplotlibrc

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Correlation heatmap
plt.figure(figsize=(12, 8))
correlation = data.corr()
sns.heatmap(correlation, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[78], line 5
#       2 import matplotlib.pyplot as plt
#       4 # Correlation heatmap
# ----> 5 plt.figure(figsize=(12, 8))
#       6 correlation = data.corr()
#       7 sns.heatmap(correlation, annot=True, cmap="coolwarm", fmt=".2f")
#
# File ~/Documents/Projects/Agents/Healthcare-Agent/venv/lib/python3.12/site-packages/matplotlib/pyplot.py:1042, in figure(num, figsize, dpi, facecolor, edgecolor, frameon, FigureClass, clear, **kwargs)
#    1032 if len(allnums) == max_open_warning >= 1:
#    1033     _api.warn_external(
#    1034         f"More than {max_open_warning} figures have been opened. "
#    1035         f"Figures created through the pyplot interface "
#    (...)
#    1039         f"Consider using `matplotlib.pyplot.close()`.",
#    1040         RuntimeWarning)
# -> 1042 manager = new_figure_manager(
# ...

# %%
import matplotlib.backends

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Correlation heatmap
plt.figure(figsize=(12, 8))
correlation = data.corr()
sns.heatmap(correlation, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[84], line 6
#       4 # Correlation heatmap
#       5 plt.figure(figsize=(12, 8))
# ----> 6 correlation = data.corr()
#       7 sns.heatmap(correlation, annot=True, cmap="coolwarm", fmt=".2f")
#       8 plt.title("Correlation Heatmap")
#
# File ~/Documents/Projects/Agents/Healthcare-Agent/venv/lib/python3.12/site-packages/pandas/core/frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~/Documents/Projects/Agents/Healthcare-Agent/venv/lib/python3.12/site-packages/pandas/core/frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
# ...

# %%
# Select only numeric columns for correlation
numeric_data = data.select_dtypes(include=['float64', 'int64'])
correlation = numeric_data.corr()

# Generate the heatmap
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors

plt.figure(figsize=(12, 8))
sns.heatmap(correlation, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[87], line 11
#       8 import matplotlib.colors as mcolors
#      10 plt.figure(figsize=(12, 8))
# ---> 11 sns.heatmap(correlation, annot=True, cmap="coolwarm", fmt=".2f")
#      12 plt.title("Correlation Heatmap")
#      13 plt.show()
#
# File ~/Documents/Projects/Agents/Healthcare-Agent/venv/lib/python3.12/site-packages/seaborn/matrix.py:456, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     454 # Draw the plot and return the Axes
#     455 if ax is None:
# --> 456     ax = plt.gca()
#     457 if square:
#     458     ax.set_aspect("equal")
#
# File ~/Documents/Projects/Agents/Healthcare-Agent/venv/lib/python3.12/site-packages/matplotlib/pyplot.py:2776, in gca()
# ...
